# %% [markdown]
# # Web Logs Visualization
#
# Визуализация результатов анализа web-логов.
#
# Ноутбук запускает генерацию графиков из TSV-файлов и отображает готовые PNG-изображения из папки `visualization/charts/`.

# %%
from pathlib import Path
import subprocess
import sys
from IPython.display import Image, display

cwd = Path.cwd()
PROJECT_DIR = cwd if (cwd / 'visualization').exists() else cwd.parent
CHARTS_DIR = PROJECT_DIR / 'visualization' / 'charts'
GENERATE_SCRIPT = PROJECT_DIR / 'visualization' / 'generate_charts.py'

print('Project directory:', PROJECT_DIR)
print('Charts directory:', CHARTS_DIR)

subprocess.run([sys.executable, str(GENERATE_SCRIPT)], check=True)

# %% [markdown]
# ## 1. Распределение HTTP-кодов

# %%
display(Image(filename=str(CHARTS_DIR / 'status_counts.png')))

# %% [markdown]
# ## 2. Топ URL

# %%
display(Image(filename=str(CHARTS_DIR / 'url_counts.png')))

# %% [markdown]
# ## 3. Топ IP-адресов

# %%
display(Image(filename=str(CHARTS_DIR / 'ip_counts.png')))

# %% [markdown]
# ## 4. Распределение HTTP-методов

# %%
display(Image(filename=str(CHARTS_DIR / 'method_counts.png')))

# %% [markdown]
# ## 5. Количество запросов по минутам

# %%
display(Image(filename=str(CHARTS_DIR / 'minute_requests.png')))

# %% [markdown]
# ## 6. Ошибки 4xx/5xx по минутам

# %%
display(Image(filename=str(CHARTS_DIR / 'minute_errors.png')))
